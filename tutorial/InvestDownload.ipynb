# %%
import numpy as np 
import pandas as pd
from pandas_datareader import data as web 
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates 
# %matplotlib inline
import yfinance as yf
import datetime as dt # For defining dates
import mplfinance as mpf # Matplotlib finance

import time

# %% [markdown]
# ### Constants

# %%
# Change this to your location 
PATH = r"/Users/charliecoleman/Documents/investing_data/stocks/"

# %% [markdown]
# ### Get Column Data From CSVs

# %%
def get_column_from_csv(file, col_name):
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File does not exist")
    else:
        return df[col_name]

# %% [markdown]
# ### Get Stock Tickers

# %%
tickers = get_column_from_csv("/Users/charliecoleman/Documents/investing_data/Wilshire-5000-Stocks-New.csv", "Ticker")
print(len(tickers))
# Out:
# 3481

# %% [markdown]
# ### Save Stock Data to CSV

# %%
# Function to get a dataframe by providing a ticker and starting data
def save_to_csv_from_yahoo(folder, ticker):
    stock = yf.Ticker(ticker)

    try:
        print("Get Data for: ", ticker)
        # Get historical closing price data 
        df = stock.history(period="5y")

        # Wait  2 seconds
        time.sleep(2)

        # Remove the period for saving the file name
        # Save data to a CSV file 
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)

    except Exception as ex:
        print("Couldn't Get Data :", ticker)

# %% [markdown]
# ### Download All Stocks

# %%
for x in range(0, 3481):
    save_to_csv_from_yahoo(PATH, tickers[x])
    print(f"{tickers[x]} downloaded" )
# Out:
# Get Data for:  A
# /Users/charliecoleman/Documents/investing_data/stocks/A.csv  Saved
# A downloaded
# Get Data for:  AA
# /Users/charliecoleman/Documents/investing_data/stocks/AA.csv  Saved
# AA downloaded
# Get Data for:  AAL
# /Users/charliecoleman/Documents/investing_data/stocks/AAL.csv  Saved
# AAL downloaded
# Get Data for:  AAME
# /Users/charliecoleman/Documents/investing_data/stocks/AAME.csv  Saved
# AAME downloaded
# Get Data for:  AAN
# /Users/charliecoleman/Documents/investing_data/stocks/AAN.csv  Saved
# AAN downloaded
# Get Data for:  AAOI
# /Users/charliecoleman/Documents/investing_data/stocks/AAOI.csv  Saved
# AAOI downloaded
# Get Data for:  AAON
# /Users/charliecoleman/Documents/investing_data/stocks/AAON.csv  Saved
# AAON downloaded
# Get Data for:  AAP
# /Users/charliecoleman/Documents/investing_data/stocks/AAP.csv  Saved
# AAP downloaded
# Get Data for:  AAPL
# /Users/charliecoleman/Documents/investing_data/stocks/AAPL.csv  Saved
# AAPL downloaded
# Get Data for:  AAT
# /Users/charliecoleman/Documents/investing_data/stocks/AAT.csv  Saved
# AAT downloaded
# Get Data for:  AAWW
# /Users/charliecoleman/Documents/investing_data/stocks/AAWW.csv  Saved
# AAWW downloaded
# Get Data for:  AAXN
# - AAXN: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/AAXN.csv  Saved
# AAXN downloaded
# Get Data for:  ABBV
# /Users/charliecoleman/Documents/investing_data/stocks/ABBV.csv  Saved
# ABBV downloaded
# Get Data for:  ABC
# /Users/charliecoleman/Documents/investing_data/stocks/ABC.csv  Saved
# ABC downloaded
# Get Data for:  ABCB
# /Users/charliecoleman/Documents/investing_data/stocks/ABCB.csv  Saved
# ABCB downloaded
# Get Data for:  ABEO
# /Users/charliecoleman/Documents/investing_data/stocks/ABEO.csv  Saved
# ABEO downloaded
# Get Data for:  ABG
# /Users/charliecoleman/Documents/investing_data/stocks/ABG.csv  Saved
# ABG downloaded
# Get Data for:  ABIO
# /Users/charliecoleman/Documents/investing_data/stocks/ABIO.csv  Saved
# ABIO downloaded
# Get Data for:  ABM
# /Users/charliecoleman/Documents/investing_data/stocks/ABM.csv  Saved
# ABM downloaded
# Get Data for:  ABMD
# /Users/charliecoleman/Documents/investing_data/stocks/ABMD.csv  Saved
# ABMD downloaded
# Get Data for:  ABR
# /Users/charliecoleman/Documents/investing_data/stocks/ABR.csv  Saved
# ABR downloaded
# Get Data for:  ABT
# /Users/charliecoleman/Documents/investing_data/stocks/ABT.csv  Saved
# ABT downloaded
# Get Data for:  ABTX
# /Users/charliecoleman/Documents/investing_data/stocks/ABTX.csv  Saved
# ABTX downloaded
# Get Data for:  AC
# /Users/charliecoleman/Documents/investing_data/stocks/AC.csv  Saved
# AC downloaded
# Get Data for:  ACA
# /Users/charliecoleman/Documents/investing_data/stocks/ACA.csv  Saved
# ACA downloaded
# Get Data for:  ACAD
# /Users/charliecoleman/Documents/investing_data/stocks/ACAD.csv  Saved
# ACAD downloaded
# Get Data for:  ACBI
# /Users/charliecoleman/Documents/investing_data/stocks/ACBI.csv  Saved
# ACBI downloaded
# Get Data for:  ACC
# /Users/charliecoleman/Documents/investing_data/stocks/ACC.csv  Saved
# ACC downloaded
# Get Data for:  ACCO
# /Users/charliecoleman/Documents/investing_data/stocks/ACCO.csv  Saved
# ACCO downloaded
# Get Data for:  ACER
# /Users/charliecoleman/Documents/investing_data/stocks/ACER.csv  Saved
# ACER downloaded
# Get Data for:  ACGL
# /Users/charliecoleman/Documents/investing_data/stocks/ACGL.csv  Saved
# ACGL downloaded
# Get Data for:  ACHC
# /Users/charliecoleman/Documents/investing_data/stocks/ACHC.csv  Saved
# ACHC downloaded
# Get Data for:  ACHV
# /Users/charliecoleman/Documents/investing_data/stocks/ACHV.csv  Saved
# ACHV downloaded
# Get Data for:  ACIA
# - ACIA: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/ACIA.csv  Saved
# ACIA downloaded
# Get Data for:  ACIW
# /Users/charliecoleman/Documents/investing_data/stocks/ACIW.csv  Saved
# ACIW downloaded
# Get Data for:  ACLS
# /Users/charliecoleman/Documents/investing_data/stocks/ACLS.csv  Saved
# ACLS downloaded
# Get Data for:  ACM
# /Users/charliecoleman/Documents/investing_data/stocks/ACM.csv  Saved
# ACM downloaded
# Get Data for:  ACMR
# /Users/charliecoleman/Documents/investing_data/stocks/ACMR.csv  Saved
# ACMR downloaded
# Get Data for:  ACN
# /Users/charliecoleman/Documents/investing_data/stocks/ACN.csv  Saved
# ACN downloaded
# Get Data for:  ACNB
# /Users/charliecoleman/Documents/investing_data/stocks/ACNB.csv  Saved
# ACNB downloaded
# Get Data for:  ACOR
# /Users/charliecoleman/Documents/investing_data/stocks/ACOR.csv  Saved
# ACOR downloaded
# Get Data for:  ACRE
# /Users/charliecoleman/Documents/investing_data/stocks/ACRE.csv  Saved
# ACRE downloaded
# Get Data for:  ACRS
# /Users/charliecoleman/Documents/investing_data/stocks/ACRS.csv  Saved
# ACRS downloaded
# Get Data for:  ACRX
# /Users/charliecoleman/Documents/investing_data/stocks/ACRX.csv  Saved
# ACRX downloaded
# Get Data for:  ACTG
# /Users/charliecoleman/Documents/investing_data/stocks/ACTG.csv  Saved
# ACTG downloaded
# Get Data for:  ACU
# /Users/charliecoleman/Documents/investing_data/stocks/ACU.csv  Saved
# ACU downloaded
# Get Data for:  ACY
# /Users/charliecoleman/Documents/investing_data/stocks/ACY.csv  Saved
# ACY downloaded
# Get Data for:  ADBE
# /Users/charliecoleman/Documents/investing_data/stocks/ADBE.csv  Saved
# ADBE downloaded
# Get Data for:  ADC
# /Users/charliecoleman/Documents/investing_data/stocks/ADC.csv  Saved
# ADC downloaded
# Get Data for:  ADES
# /Users/charliecoleman/Documents/investing_data/stocks/ADES.csv  Saved
# ADES downloaded
# Get Data for:  ADI
# /Users/charliecoleman/Documents/investing_data/stocks/ADI.csv  Saved
# ADI downloaded
# Get Data for:  ADM
# /Users/charliecoleman/Documents/investing_data/stocks/ADM.csv  Saved
# ADM downloaded
# Get Data for:  ADMA
# /Users/charliecoleman/Documents/investing_data/stocks/ADMA.csv  Saved
# ADMA downloaded
# Get Data for:  ADMP
# /Users/charliecoleman/Documents/investing_data/stocks/ADMP.csv  Saved
# ADMP downloaded
# Get Data for:  ADMS
# - ADMS: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/ADMS.csv  Saved
# ADMS downloaded
# Get Data for:  ADNT
# /Users/charliecoleman/Documents/investing_data/stocks/ADNT.csv  Saved
# ADNT downloaded
# Get Data for:  ADP
# /Users/charliecoleman/Documents/investing_data/stocks/ADP.csv  Saved
# ADP downloaded
# Get Data for:  ADRO
# - ADRO: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/ADRO.csv  Saved
# ADRO downloaded
# Get Data for:  ADS
# /Users/charliecoleman/Documents/investing_data/stocks/ADS.csv  Saved
# ADS downloaded
# Get Data for:  ADSK
# /Users/charliecoleman/Documents/investing_data/stocks/ADSK.csv  Saved
# ADSK downloaded
# Get Data for:  ADSW
# - ADSW: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/ADSW.csv  Saved
# ADSW downloaded
# Get Data for:  ADT
# /Users/charliecoleman/Documents/investing_data/stocks/ADT.csv  Saved
# ADT downloaded
# Get Data for:  ADTN
# /Users/charliecoleman/Documents/investing_data/stocks/ADTN.csv  Saved
# ADTN downloaded
# Get Data for:  ADUS
# /Users/charliecoleman/Documents/investing_data/stocks/ADUS.csv  Saved
# ADUS downloaded
# Get Data for:  ADVM
# /Users/charliecoleman/Documents/investing_data/stocks/ADVM.csv  Saved
# ADVM downloaded
# Get Data for:  ADXS
# /Users/charliecoleman/Documents/investing_data/stocks/ADXS.csv  Saved
# ADXS downloaded
# Get Data for:  AE
# /Users/charliecoleman/Documents/investing_data/stocks/AE.csv  Saved
# AE downloaded
# Get Data for:  AEE
# /Users/charliecoleman/Documents/investing_data/stocks/AEE.csv  Saved
# AEE downloaded
# Get Data for:  AEGN
# - AEGN: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/AEGN.csv  Saved
# AEGN downloaded
# Get Data for:  AEHR
# /Users/charliecoleman/Documents/investing_data/stocks/AEHR.csv  Saved
# AEHR downloaded
# Get Data for:  AEIS
# /Users/charliecoleman/Documents/investing_data/stocks/AEIS.csv  Saved
# AEIS downloaded
# Get Data for:  AEL
# /Users/charliecoleman/Documents/investing_data/stocks/AEL.csv  Saved
# AEL downloaded
# Get Data for:  AEMD
# /Users/charliecoleman/Documents/investing_data/stocks/AEMD.csv  Saved
# AEMD downloaded
# Get Data for:  AEO
# /Users/charliecoleman/Documents/investing_data/stocks/AEO.csv  Saved
# AEO downloaded
# Get Data for:  AEP
# /Users/charliecoleman/Documents/investing_data/stocks/AEP.csv  Saved
# AEP downloaded
# Get Data for:  AERI
# /Users/charliecoleman/Documents/investing_data/stocks/AERI.csv  Saved
# AERI downloaded
# Get Data for:  AES
# /Users/charliecoleman/Documents/investing_data/stocks/AES.csv  Saved
# AES downloaded
# Get Data for:  AEY
# /Users/charliecoleman/Documents/investing_data/stocks/AEY.csv  Saved
# AEY downloaded
# Get Data for:  AFG
# /Users/charliecoleman/Documents/investing_data/stocks/AFG.csv  Saved
# AFG downloaded
# Get Data for:  AFH
# - AFH: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/AFH.csv  Saved
# AFH downloaded
# Get Data for:  AFI
# /Users/charliecoleman/Documents/investing_data/stocks/AFI.csv  Saved
# AFI downloaded
# Get Data for:  AFIN
# /Users/charliecoleman/Documents/investing_data/stocks/AFIN.csv  Saved
# AFIN downloaded
# Get Data for:  AFL
# /Users/charliecoleman/Documents/investing_data/stocks/AFL.csv  Saved
# AFL downloaded
# Get Data for:  AGCO
# /Users/charliecoleman/Documents/investing_data/stocks/AGCO.csv  Saved
# AGCO downloaded
# Get Data for:  AGE
# /Users/charliecoleman/Documents/investing_data/stocks/AGE.csv  Saved
# AGE downloaded
# Get Data for:  AGEN
# /Users/charliecoleman/Documents/investing_data/stocks/AGEN.csv  Saved
# AGEN downloaded
# Get Data for:  AGFS
# /Users/charliecoleman/Documents/investing_data/stocks/AGFS.csv  Saved
# AGFS downloaded
# Get Data for:  AGIO
# /Users/charliecoleman/Documents/investing_data/stocks/AGIO.csv  Saved
# AGIO downloaded
# Get Data for:  AGLE
# /Users/charliecoleman/Documents/investing_data/stocks/AGLE.csv  Saved
# AGLE downloaded
# Get Data for:  AGM
# /Users/charliecoleman/Documents/investing_data/stocks/AGM.csv  Saved
# AGM downloaded
# Get Data for:  AGNC
# /Users/charliecoleman/Documents/investing_data/stocks/AGNC.csv  Saved
# AGNC downloaded
# Get Data for:  AGO
# /Users/charliecoleman/Documents/investing_data/stocks/AGO.csv  Saved
# AGO downloaded
# Get Data for:  AGR
# /Users/charliecoleman/Documents/investing_data/stocks/AGR.csv  Saved
# AGR downloaded
# Get Data for:  AGRX
# /Users/charliecoleman/Documents/investing_data/stocks/AGRX.csv  Saved
# AGRX downloaded
# Get Data for:  AGS
# /Users/charliecoleman/Documents/investing_data/stocks/AGS.csv  Saved
# AGS downloaded
# Get Data for:  AGTC
# /Users/charliecoleman/Documents/investing_data/stocks/AGTC.csv  Saved
# AGTC downloaded
# Get Data for:  AGX
# /Users/charliecoleman/Documents/investing_data/stocks/AGX.csv  Saved
# AGX downloaded
# Get Data for:  AGYS
# /Users/charliecoleman/Documents/investing_data/stocks/AGYS.csv  Saved
# AGYS downloaded
# Get Data for:  AHC
# - AHC: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/AHC.csv  Saved
# AHC downloaded
# Get Data for:  AHH
# /Users/charliecoleman/Documents/investing_data/stocks/AHH.csv  Saved
# AHH downloaded
# Get Data for:  AHT
# /Users/charliecoleman/Documents/investing_data/stocks/AHT.csv  Saved
# AHT downloaded
# Get Data for:  AIG
# /Users/charliecoleman/Documents/investing_data/stocks/AIG.csv  Saved
# AIG downloaded
# Get Data for:  AIMC
# /Users/charliecoleman/Documents/investing_data/stocks/AIMC.csv  Saved
# AIMC downloaded
# Get Data for:  AIMT
# - AIMT: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/AIMT.csv  Saved
# AIMT downloaded
# Get Data for:  AIN
# /Users/charliecoleman/Documents/investing_data/stocks/AIN.csv  Saved
# AIN downloaded
# Get Data for:  AINC
# /Users/charliecoleman/Documents/investing_data/stocks/AINC.csv  Saved
# AINC downloaded
# Get Data for:  AIR
# /Users/charliecoleman/Documents/investing_data/stocks/AIR.csv  Saved
# AIR downloaded
# Get Data for:  AIRG
# /Users/charliecoleman/Documents/investing_data/stocks/AIRG.csv  Saved
# AIRG downloaded
# Get Data for:  AIRI
# /Users/charliecoleman/Documents/investing_data/stocks/AIRI.csv  Saved
# AIRI downloaded
# Get Data for:  AIRT
# /Users/charliecoleman/Documents/investing_data/stocks/AIRT.csv  Saved
# AIRT downloaded
# Get Data for:  AIT
# /Users/charliecoleman/Documents/investing_data/stocks/AIT.csv  Saved
# AIT downloaded
# Get Data for:  AIV
# /Users/charliecoleman/Documents/investing_data/stocks/AIV.csv  Saved
# AIV downloaded
# Get Data for:  AIZ
# /Users/charliecoleman/Documents/investing_data/stocks/AIZ.csv  Saved
# AIZ downloaded
# Get Data for:  AJG
# /Users/charliecoleman/Documents/investing_data/stocks/AJG.csv  Saved
# AJG downloaded
# Get Data for:  AJRD
# /Users/charliecoleman/Documents/investing_data/stocks/AJRD.csv  Saved
# AJRD downloaded
# Get Data for:  AJX
# /Users/charliecoleman/Documents/investing_data/stocks/AJX.csv  Saved
# AJX downloaded
# Get Data for:  AKAM
# /Users/charliecoleman/Documents/investing_data/stocks/AKAM.csv  Saved
# AKAM downloaded
# Get Data for:  AKBA
# /Users/charliecoleman/Documents/investing_data/stocks/AKBA.csv  Saved
# AKBA downloaded
# Get Data for:  AKCA
# - AKCA: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/AKCA.csv  Saved
# AKCA downloaded
# Get Data for:  AKER
# - AKER: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/AKER.csv  Saved
# AKER downloaded
# Get Data for:  AKR
# /Users/charliecoleman/Documents/investing_data/stocks/AKR.csv  Saved
# AKR downloaded
# Get Data for:  AKTS
# /Users/charliecoleman/Documents/investing_data/stocks/AKTS.csv  Saved
# AKTS downloaded
# Get Data for:  AL
# /Users/charliecoleman/Documents/investing_data/stocks/AL.csv  Saved
# AL downloaded
# Get Data for:  ALB
# /Users/charliecoleman/Documents/investing_data/stocks/ALB.csv  Saved
# ALB downloaded
# Get Data for:  ALBO
# /Users/charliecoleman/Documents/investing_data/stocks/ALBO.csv  Saved
# ALBO downloaded
# Get Data for:  ALCO
# /Users/charliecoleman/Documents/investing_data/stocks/ALCO.csv  Saved
# ALCO downloaded
# Get Data for:  ALDX
# /Users/charliecoleman/Documents/investing_data/stocks/ALDX.csv  Saved
# ALDX downloaded
# Get Data for:  ALE
# /Users/charliecoleman/Documents/investing_data/stocks/ALE.csv  Saved
# ALE downloaded
# Get Data for:  ALEC
# /Users/charliecoleman/Documents/investing_data/stocks/ALEC.csv  Saved
# ALEC downloaded
# Get Data for:  ALEX
# /Users/charliecoleman/Documents/investing_data/stocks/ALEX.csv  Saved
# ALEX downloaded
# Get Data for:  ALG
# /Users/charliecoleman/Documents/investing_data/stocks/ALG.csv  Saved
# ALG downloaded
# Get Data for:  ALGN
# /Users/charliecoleman/Documents/investing_data/stocks/ALGN.csv  Saved
# ALGN downloaded
# Get Data for:  ALGT
# /Users/charliecoleman/Documents/investing_data/stocks/ALGT.csv  Saved
# ALGT downloaded
# Get Data for:  ALIM
# /Users/charliecoleman/Documents/investing_data/stocks/ALIM.csv  Saved
# ALIM downloaded
# Get Data for:  ALJJ
# /Users/charliecoleman/Documents/investing_data/stocks/ALJJ.csv  Saved
# ALJJ downloaded
# Get Data for:  ALK
# /Users/charliecoleman/Documents/investing_data/stocks/ALK.csv  Saved
# ALK downloaded
# Get Data for:  ALKS
# /Users/charliecoleman/Documents/investing_data/stocks/ALKS.csv  Saved
# ALKS downloaded
# Get Data for:  ALL
# /Users/charliecoleman/Documents/investing_data/stocks/ALL.csv  Saved
# ALL downloaded
# Get Data for:  ALLE
# /Users/charliecoleman/Documents/investing_data/stocks/ALLE.csv  Saved
# ALLE downloaded
# Get Data for:  ALLK
# /Users/charliecoleman/Documents/investing_data/stocks/ALLK.csv  Saved
# ALLK downloaded
# Get Data for:  ALLO
# /Users/charliecoleman/Documents/investing_data/stocks/ALLO.csv  Saved
# ALLO downloaded
# Get Data for:  ALLY
# /Users/charliecoleman/Documents/investing_data/stocks/ALLY.csv  Saved
# ALLY downloaded
# Get Data for:  ALNA
# /Users/charliecoleman/Documents/investing_data/stocks/ALNA.csv  Saved
# ALNA downloaded
# Get Data for:  ALNY
# /Users/charliecoleman/Documents/investing_data/stocks/ALNY.csv  Saved
# ALNY downloaded
# Get Data for:  ALOT
# /Users/charliecoleman/Documents/investing_data/stocks/ALOT.csv  Saved
# ALOT downloaded
# Get Data for:  ALPN
# /Users/charliecoleman/Documents/investing_data/stocks/ALPN.csv  Saved
# ALPN downloaded
# Get Data for:  ALRM
# /Users/charliecoleman/Documents/investing_data/stocks/ALRM.csv  Saved
# ALRM downloaded
# Get Data for:  ALSK
# - ALSK: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/ALSK.csv  Saved
# ALSK downloaded
# Get Data for:  ALSN
# /Users/charliecoleman/Documents/investing_data/stocks/ALSN.csv  Saved
# ALSN downloaded
# Get Data for:  ALT
# /Users/charliecoleman/Documents/investing_data/stocks/ALT.csv  Saved
# ALT downloaded
# Get Data for:  ALTM
# /Users/charliecoleman/Documents/investing_data/stocks/ALTM.csv  Saved
# ALTM downloaded
# Get Data for:  ALTR
# /Users/charliecoleman/Documents/investing_data/stocks/ALTR.csv  Saved
# ALTR downloaded
# Get Data for:  ALV
# /Users/charliecoleman/Documents/investing_data/stocks/ALV.csv  Saved
# ALV downloaded
# Get Data for:  ALX
# /Users/charliecoleman/Documents/investing_data/stocks/ALX.csv  Saved
# ALX downloaded
# Get Data for:  ALXN
# - ALXN: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/ALXN.csv  Saved
# ALXN downloaded
# Get Data for:  AM
# /Users/charliecoleman/Documents/investing_data/stocks/AM.csv  Saved
# AM downloaded
# Get Data for:  AMAG
# - AMAG: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/AMAG.csv  Saved
# AMAG downloaded
# Get Data for:  AMAL
# /Users/charliecoleman/Documents/investing_data/stocks/AMAL.csv  Saved
# AMAL downloaded
# Get Data for:  AMAT
# /Users/charliecoleman/Documents/investing_data/stocks/AMAT.csv  Saved
# AMAT downloaded
# Get Data for:  AMBC
# /Users/charliecoleman/Documents/investing_data/stocks/AMBC.csv  Saved
# AMBC downloaded
# Get Data for:  AMC
# /Users/charliecoleman/Documents/investing_data/stocks/AMC.csv  Saved
# AMC downloaded
# Get Data for:  AMCX
# /Users/charliecoleman/Documents/investing_data/stocks/AMCX.csv  Saved
# AMCX downloaded
# Get Data for:  AMD
# /Users/charliecoleman/Documents/investing_data/stocks/AMD.csv  Saved
# AMD downloaded
# Get Data for:  AME
# /Users/charliecoleman/Documents/investing_data/stocks/AME.csv  Saved
# AME downloaded
# Get Data for:  AMED
# /Users/charliecoleman/Documents/investing_data/stocks/AMED.csv  Saved
# AMED downloaded
# Get Data for:  AMG
# /Users/charliecoleman/Documents/investing_data/stocks/AMG.csv  Saved
# AMG downloaded
# Get Data for:  AMGN
# /Users/charliecoleman/Documents/investing_data/stocks/AMGN.csv  Saved
# AMGN downloaded
# Get Data for:  AMH
# /Users/charliecoleman/Documents/investing_data/stocks/AMH.csv  Saved
# AMH downloaded
# Get Data for:  AMKR
# /Users/charliecoleman/Documents/investing_data/stocks/AMKR.csv  Saved
# AMKR downloaded
# Get Data for:  AMN
# /Users/charliecoleman/Documents/investing_data/stocks/AMN.csv  Saved
# AMN downloaded
# Get Data for:  AMNB
# /Users/charliecoleman/Documents/investing_data/stocks/AMNB.csv  Saved
# AMNB downloaded
# Get Data for:  AMOT
# /Users/charliecoleman/Documents/investing_data/stocks/AMOT.csv  Saved
# AMOT downloaded
# Get Data for:  AMP
# /Users/charliecoleman/Documents/investing_data/stocks/AMP.csv  Saved
# AMP downloaded
# Get Data for:  AMPE
# /Users/charliecoleman/Documents/investing_data/stocks/AMPE.csv  Saved
# AMPE downloaded
# Get Data for:  AMPH
# /Users/charliecoleman/Documents/investing_data/stocks/AMPH.csv  Saved
# AMPH downloaded
# Get Data for:  AMRB
# - AMRB: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/AMRB.csv  Saved
# AMRB downloaded
# Get Data for:  AMRC
# /Users/charliecoleman/Documents/investing_data/stocks/AMRC.csv  Saved
# AMRC downloaded
# Get Data for:  AMRK
# /Users/charliecoleman/Documents/investing_data/stocks/AMRK.csv  Saved
# AMRK downloaded
# Get Data for:  AMRS
# /Users/charliecoleman/Documents/investing_data/stocks/AMRS.csv  Saved
# AMRS downloaded
# Get Data for:  AMRX
# /Users/charliecoleman/Documents/investing_data/stocks/AMRX.csv  Saved
# AMRX downloaded
# Get Data for:  AMS
# /Users/charliecoleman/Documents/investing_data/stocks/AMS.csv  Saved
# AMS downloaded
# Get Data for:  AMSC
# /Users/charliecoleman/Documents/investing_data/stocks/AMSC.csv  Saved
# AMSC downloaded
# Get Data for:  AMSF
# /Users/charliecoleman/Documents/investing_data/stocks/AMSF.csv  Saved
# AMSF downloaded
# Get Data for:  AMSWA
# /Users/charliecoleman/Documents/investing_data/stocks/AMSWA.csv  Saved
# AMSWA downloaded
# Get Data for:  AMT
# /Users/charliecoleman/Documents/investing_data/stocks/AMT.csv  Saved
# AMT downloaded
# Get Data for:  AMTD
# /Users/charliecoleman/Documents/investing_data/stocks/AMTD.csv  Saved
# AMTD downloaded
# Get Data for:  AMTX
# /Users/charliecoleman/Documents/investing_data/stocks/AMTX.csv  Saved
# AMTX downloaded
# Get Data for:  AMWD
# /Users/charliecoleman/Documents/investing_data/stocks/AMWD.csv  Saved
# AMWD downloaded
# Get Data for:  AMZN
# /Users/charliecoleman/Documents/investing_data/stocks/AMZN.csv  Saved
# AMZN downloaded
# Get Data for:  AN
# /Users/charliecoleman/Documents/investing_data/stocks/AN.csv  Saved
# AN downloaded
# Get Data for:  ANAB
# /Users/charliecoleman/Documents/investing_data/stocks/ANAB.csv  Saved
# ANAB downloaded
# Get Data for:  ANAT
# /Users/charliecoleman/Documents/investing_data/stocks/ANAT.csv  Saved
# ANAT downloaded
# Get Data for:  ANDE
# /Users/charliecoleman/Documents/investing_data/stocks/ANDE.csv  Saved
# ANDE downloaded
# Get Data for:  ANET
# /Users/charliecoleman/Documents/investing_data/stocks/ANET.csv  Saved
# ANET downloaded
# Get Data for:  ANF
# /Users/charliecoleman/Documents/investing_data/stocks/ANF.csv  Saved
# ANF downloaded
# Get Data for:  ANGI
# /Users/charliecoleman/Documents/investing_data/stocks/ANGI.csv  Saved
# ANGI downloaded
# Get Data for:  ANGO
# /Users/charliecoleman/Documents/investing_data/stocks/ANGO.csv  Saved
# ANGO downloaded
# Get Data for:  ANH
# - ANH: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/ANH.csv  Saved
# ANH downloaded
# Get Data for:  ANIK
# /Users/charliecoleman/Documents/investing_data/stocks/ANIK.csv  Saved
# ANIK downloaded
# Get Data for:  ANIP
# /Users/charliecoleman/Documents/investing_data/stocks/ANIP.csv  Saved
# ANIP downloaded
# Get Data for:  ANIX
# /Users/charliecoleman/Documents/investing_data/stocks/ANIX.csv  Saved
# ANIX downloaded
# Get Data for:  ANSS
# /Users/charliecoleman/Documents/investing_data/stocks/ANSS.csv  Saved
# ANSS downloaded
# Get Data for:  ANTM
# /Users/charliecoleman/Documents/investing_data/stocks/ANTM.csv  Saved
# ANTM downloaded
# Get Data for:  AON
# /Users/charliecoleman/Documents/investing_data/stocks/AON.csv  Saved
# AON downloaded
# Get Data for:  AOS
# /Users/charliecoleman/Documents/investing_data/stocks/AOS.csv  Saved
# AOS downloaded
# Get Data for:  AOSL
# /Users/charliecoleman/Documents/investing_data/stocks/AOSL.csv  Saved
# AOSL downloaded
# Get Data for:  AP
# /Users/charliecoleman/Documents/investing_data/stocks/AP.csv  Saved
# AP downloaded
# Get Data for:  APA
# /Users/charliecoleman/Documents/investing_data/stocks/APA.csv  Saved
# APA downloaded
# Get Data for:  APAM
# /Users/charliecoleman/Documents/investing_data/stocks/APAM.csv  Saved
# APAM downloaded
# Get Data for:  APD
# /Users/charliecoleman/Documents/investing_data/stocks/APD.csv  Saved
# APD downloaded
# Get Data for:  APDN
# /Users/charliecoleman/Documents/investing_data/stocks/APDN.csv  Saved
# APDN downloaded
# Get Data for:  APEI
# /Users/charliecoleman/Documents/investing_data/stocks/APEI.csv  Saved
# APEI downloaded
# Get Data for:  APEN
# /Users/charliecoleman/Documents/investing_data/stocks/APEN.csv  Saved
# APEN downloaded
# Get Data for:  APH
# /Users/charliecoleman/Documents/investing_data/stocks/APH.csv  Saved
# APH downloaded
# Get Data for:  APLE
# /Users/charliecoleman/Documents/investing_data/stocks/APLE.csv  Saved
# APLE downloaded
# Get Data for:  APLS
# /Users/charliecoleman/Documents/investing_data/stocks/APLS.csv  Saved
# APLS downloaded
# Get Data for:  APOG
# /Users/charliecoleman/Documents/investing_data/stocks/APOG.csv  Saved
# APOG downloaded
# Get Data for:  APPF
# /Users/charliecoleman/Documents/investing_data/stocks/APPF.csv  Saved
# APPF downloaded
# Get Data for:  APPN
# /Users/charliecoleman/Documents/investing_data/stocks/APPN.csv  Saved
# APPN downloaded
# Get Data for:  APPS
# /Users/charliecoleman/Documents/investing_data/stocks/APPS.csv  Saved
# APPS downloaded
# Get Data for:  APRN
# /Users/charliecoleman/Documents/investing_data/stocks/APRN.csv  Saved
# APRN downloaded
# Get Data for:  APT
# /Users/charliecoleman/Documents/investing_data/stocks/APT.csv  Saved
# APT downloaded
# Get Data for:  APTS
# /Users/charliecoleman/Documents/investing_data/stocks/APTS.csv  Saved
# APTS downloaded
# Get Data for:  APTV
# /Users/charliecoleman/Documents/investing_data/stocks/APTV.csv  Saved
# APTV downloaded
# Get Data for:  APVO
# /Users/charliecoleman/Documents/investing_data/stocks/APVO.csv  Saved
# APVO downloaded
# Get Data for:  APYX
# /Users/charliecoleman/Documents/investing_data/stocks/APYX.csv  Saved
# APYX downloaded
# Get Data for:  AQB
# /Users/charliecoleman/Documents/investing_data/stocks/AQB.csv  Saved
# AQB downloaded
# Get Data for:  AQMS
# /Users/charliecoleman/Documents/investing_data/stocks/AQMS.csv  Saved
# AQMS downloaded
# Get Data for:  AQUA
# /Users/charliecoleman/Documents/investing_data/stocks/AQUA.csv  Saved
# AQUA downloaded
# Get Data for:  AR
# /Users/charliecoleman/Documents/investing_data/stocks/AR.csv  Saved
# AR downloaded
# Get Data for:  ARA
# - ARA: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/ARA.csv  Saved
# ARA downloaded
# Get Data for:  ARAV
# /Users/charliecoleman/Documents/investing_data/stocks/ARAV.csv  Saved
# ARAV downloaded
# Get Data for:  ARAY
# /Users/charliecoleman/Documents/investing_data/stocks/ARAY.csv  Saved
# ARAY downloaded
# Get Data for:  ARC
# /Users/charliecoleman/Documents/investing_data/stocks/ARC.csv  Saved
# ARC downloaded
# Get Data for:  ARCB
# /Users/charliecoleman/Documents/investing_data/stocks/ARCB.csv  Saved
# ARCB downloaded
# Get Data for:  ARCH
# /Users/charliecoleman/Documents/investing_data/stocks/ARCH.csv  Saved
# ARCH downloaded
# Get Data for:  ARDX
# /Users/charliecoleman/Documents/investing_data/stocks/ARDX.csv  Saved
# ARDX downloaded
# Get Data for:  ARE
# /Users/charliecoleman/Documents/investing_data/stocks/ARE.csv  Saved
# ARE downloaded
# Get Data for:  ARES
# /Users/charliecoleman/Documents/investing_data/stocks/ARES.csv  Saved
# ARES downloaded
# Get Data for:  ARGO
# /Users/charliecoleman/Documents/investing_data/stocks/ARGO.csv  Saved
# ARGO downloaded
# Get Data for:  ARI
# /Users/charliecoleman/Documents/investing_data/stocks/ARI.csv  Saved
# ARI downloaded
# Get Data for:  ARKR
# /Users/charliecoleman/Documents/investing_data/stocks/ARKR.csv  Saved
# ARKR downloaded
# Get Data for:  ARL
# /Users/charliecoleman/Documents/investing_data/stocks/ARL.csv  Saved
# ARL downloaded
# Get Data for:  ARLO
# /Users/charliecoleman/Documents/investing_data/stocks/ARLO.csv  Saved
# ARLO downloaded
# Get Data for:  ARMK
# /Users/charliecoleman/Documents/investing_data/stocks/ARMK.csv  Saved
# ARMK downloaded
# Get Data for:  ARNA
# /Users/charliecoleman/Documents/investing_data/stocks/ARNA.csv  Saved
# ARNA downloaded
# Get Data for:  ARNC
# /Users/charliecoleman/Documents/investing_data/stocks/ARNC.csv  Saved
# ARNC downloaded
# Get Data for:  AROC
# /Users/charliecoleman/Documents/investing_data/stocks/AROC.csv  Saved
# AROC downloaded
# Get Data for:  AROW
# /Users/charliecoleman/Documents/investing_data/stocks/AROW.csv  Saved
# AROW downloaded
# Get Data for:  ARPO
# - ARPO: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/ARPO.csv  Saved
# ARPO downloaded
# Get Data for:  ARR
# /Users/charliecoleman/Documents/investing_data/stocks/ARR.csv  Saved
# ARR downloaded
# Get Data for:  ARTNA
# /Users/charliecoleman/Documents/investing_data/stocks/ARTNA.csv  Saved
# ARTNA downloaded
# Get Data for:  ARTW
# /Users/charliecoleman/Documents/investing_data/stocks/ARTW.csv  Saved
# ARTW downloaded
# Get Data for:  ARVN
# /Users/charliecoleman/Documents/investing_data/stocks/ARVN.csv  Saved
# ARVN downloaded
# Get Data for:  ARW
# /Users/charliecoleman/Documents/investing_data/stocks/ARW.csv  Saved
# ARW downloaded
# Get Data for:  ARWR
# /Users/charliecoleman/Documents/investing_data/stocks/ARWR.csv  Saved
# ARWR downloaded
# Get Data for:  ASB
# /Users/charliecoleman/Documents/investing_data/stocks/ASB.csv  Saved
# ASB downloaded
# Get Data for:  ASFI
# - ASFI: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/ASFI.csv  Saved
# ASFI downloaded
# Get Data for:  ASGN
# /Users/charliecoleman/Documents/investing_data/stocks/ASGN.csv  Saved
# ASGN downloaded
# Get Data for:  ASH
# /Users/charliecoleman/Documents/investing_data/stocks/ASH.csv  Saved
# ASH downloaded
# Get Data for:  ASIX
# /Users/charliecoleman/Documents/investing_data/stocks/ASIX.csv  Saved
# ASIX downloaded
# Get Data for:  ASMB
# /Users/charliecoleman/Documents/investing_data/stocks/ASMB.csv  Saved
# ASMB downloaded
# Get Data for:  ASNA
# - ASNA: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/ASNA.csv  Saved
# ASNA downloaded
# Get Data for:  ASPN
# /Users/charliecoleman/Documents/investing_data/stocks/ASPN.csv  Saved
# ASPN downloaded
# Get Data for:  ASPS
# /Users/charliecoleman/Documents/investing_data/stocks/ASPS.csv  Saved
# ASPS downloaded
# Get Data for:  ASRT
# /Users/charliecoleman/Documents/investing_data/stocks/ASRT.csv  Saved
# ASRT downloaded
# Get Data for:  ASRV
# /Users/charliecoleman/Documents/investing_data/stocks/ASRV.csv  Saved
# ASRV downloaded
# Get Data for:  ASTC
# /Users/charliecoleman/Documents/investing_data/stocks/ASTC.csv  Saved
# ASTC downloaded
# Get Data for:  ASTE
# /Users/charliecoleman/Documents/investing_data/stocks/ASTE.csv  Saved
# ASTE downloaded
# Get Data for:  ASUR
# /Users/charliecoleman/Documents/investing_data/stocks/ASUR.csv  Saved
# ASUR downloaded
# Get Data for:  ASYS
# /Users/charliecoleman/Documents/investing_data/stocks/ASYS.csv  Saved
# ASYS downloaded
# Get Data for:  ATEC
# /Users/charliecoleman/Documents/investing_data/stocks/ATEC.csv  Saved
# ATEC downloaded
# Get Data for:  ATEN
# /Users/charliecoleman/Documents/investing_data/stocks/ATEN.csv  Saved
# ATEN downloaded
# Get Data for:  ATGE
# /Users/charliecoleman/Documents/investing_data/stocks/ATGE.csv  Saved
# ATGE downloaded
# Get Data for:  ATH
# /Users/charliecoleman/Documents/investing_data/stocks/ATH.csv  Saved
# ATH downloaded
# Get Data for:  ATHX
# /Users/charliecoleman/Documents/investing_data/stocks/ATHX.csv  Saved
# ATHX downloaded
# Get Data for:  ATI
# /Users/charliecoleman/Documents/investing_data/stocks/ATI.csv  Saved
# ATI downloaded
# Get Data for:  ATKR
# /Users/charliecoleman/Documents/investing_data/stocks/ATKR.csv  Saved
# ATKR downloaded
# Get Data for:  ATLC
# /Users/charliecoleman/Documents/investing_data/stocks/ATLC.csv  Saved
# ATLC downloaded
# Get Data for:  ATLO
# /Users/charliecoleman/Documents/investing_data/stocks/ATLO.csv  Saved
# ATLO downloaded
# Get Data for:  ATNI
# /Users/charliecoleman/Documents/investing_data/stocks/ATNI.csv  Saved
# ATNI downloaded
# Get Data for:  ATNM
# /Users/charliecoleman/Documents/investing_data/stocks/ATNM.csv  Saved
# ATNM downloaded
# Get Data for:  ATNX
# /Users/charliecoleman/Documents/investing_data/stocks/ATNX.csv  Saved
# ATNX downloaded
# Get Data for:  ATO
# /Users/charliecoleman/Documents/investing_data/stocks/ATO.csv  Saved
# ATO downloaded
# Get Data for:  ATOS
# /Users/charliecoleman/Documents/investing_data/stocks/ATOS.csv  Saved
# ATOS downloaded
# Get Data for:  ATR
# /Users/charliecoleman/Documents/investing_data/stocks/ATR.csv  Saved
# ATR downloaded
# Get Data for:  ATRA
# /Users/charliecoleman/Documents/investing_data/stocks/ATRA.csv  Saved
# ATRA downloaded
# Get Data for:  ATRC
# /Users/charliecoleman/Documents/investing_data/stocks/ATRC.csv  Saved
# ATRC downloaded
# Get Data for:  ATRI
# /Users/charliecoleman/Documents/investing_data/stocks/ATRI.csv  Saved
# ATRI downloaded
# Get Data for:  ATRO
# /Users/charliecoleman/Documents/investing_data/stocks/ATRO.csv  Saved
# ATRO downloaded
# Get Data for:  ATRS
# /Users/charliecoleman/Documents/investing_data/stocks/ATRS.csv  Saved
# ATRS downloaded
# Get Data for:  ATSG
# /Users/charliecoleman/Documents/investing_data/stocks/ATSG.csv  Saved
# ATSG downloaded
# Get Data for:  ATUS
# /Users/charliecoleman/Documents/investing_data/stocks/ATUS.csv  Saved
# ATUS downloaded
# Get Data for:  ATVI
# /Users/charliecoleman/Documents/investing_data/stocks/ATVI.csv  Saved
# ATVI downloaded
# Get Data for:  AUBN
# /Users/charliecoleman/Documents/investing_data/stocks/AUBN.csv  Saved
# AUBN downloaded
# Get Data for:  AUMN
# /Users/charliecoleman/Documents/investing_data/stocks/AUMN.csv  Saved
# AUMN downloaded
# Get Data for:  AUTO
# /Users/charliecoleman/Documents/investing_data/stocks/AUTO.csv  Saved
# AUTO downloaded
# Get Data for:  AVA
# /Users/charliecoleman/Documents/investing_data/stocks/AVA.csv  Saved
# AVA downloaded
# Get Data for:  AVAV
# /Users/charliecoleman/Documents/investing_data/stocks/AVAV.csv  Saved
# AVAV downloaded
# Get Data for:  AVB
# /Users/charliecoleman/Documents/investing_data/stocks/AVB.csv  Saved
# AVB downloaded
# Get Data for:  AVD
# /Users/charliecoleman/Documents/investing_data/stocks/AVD.csv  Saved
# AVD downloaded
# Get Data for:  AVEO
# /Users/charliecoleman/Documents/investing_data/stocks/AVEO.csv  Saved
# AVEO downloaded
# Get Data for:  AVGO
# /Users/charliecoleman/Documents/investing_data/stocks/AVGO.csv  Saved
# AVGO downloaded
# Get Data for:  AVGR
# /Users/charliecoleman/Documents/investing_data/stocks/AVGR.csv  Saved
# AVGR downloaded
# Get Data for:  AVID
# /Users/charliecoleman/Documents/investing_data/stocks/AVID.csv  Saved
# AVID downloaded
# Get Data for:  AVLR
# /Users/charliecoleman/Documents/investing_data/stocks/AVLR.csv  Saved
# AVLR downloaded
# Get Data for:  AVNS
# /Users/charliecoleman/Documents/investing_data/stocks/AVNS.csv  Saved
# AVNS downloaded
# Get Data for:  AVNW
# /Users/charliecoleman/Documents/investing_data/stocks/AVNW.csv  Saved
# AVNW downloaded
# Get Data for:  AVRO
# /Users/charliecoleman/Documents/investing_data/stocks/AVRO.csv  Saved
# AVRO downloaded
# Get Data for:  AVT
# /Users/charliecoleman/Documents/investing_data/stocks/AVT.csv  Saved
# AVT downloaded
# Get Data for:  AVTR
# /Users/charliecoleman/Documents/investing_data/stocks/AVTR.csv  Saved
# AVTR downloaded
# Get Data for:  AVXL
# /Users/charliecoleman/Documents/investing_data/stocks/AVXL.csv  Saved
# AVXL downloaded
# Get Data for:  AVY
# /Users/charliecoleman/Documents/investing_data/stocks/AVY.csv  Saved
# AVY downloaded
# Get Data for:  AVYA
# /Users/charliecoleman/Documents/investing_data/stocks/AVYA.csv  Saved
# AVYA downloaded
# Get Data for:  AWI
# /Users/charliecoleman/Documents/investing_data/stocks/AWI.csv  Saved
# AWI downloaded
# Get Data for:  AWK
# /Users/charliecoleman/Documents/investing_data/stocks/AWK.csv  Saved
# AWK downloaded
# Get Data for:  AWR
# /Users/charliecoleman/Documents/investing_data/stocks/AWR.csv  Saved
# AWR downloaded
# Get Data for:  AWRE
# /Users/charliecoleman/Documents/investing_data/stocks/AWRE.csv  Saved
# AWRE downloaded
# Get Data for:  AWSM
# - AWSM: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/AWSM.csv  Saved
# AWSM downloaded
# Get Data for:  AX
# /Users/charliecoleman/Documents/investing_data/stocks/AX.csv  Saved
# AX downloaded
# Get Data for:  AXAS
# /Users/charliecoleman/Documents/investing_data/stocks/AXAS.csv  Saved
# AXAS downloaded
# Get Data for:  AXDX
# /Users/charliecoleman/Documents/investing_data/stocks/AXDX.csv  Saved
# AXDX downloaded
# Get Data for:  AXE
# - AXE: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/AXE.csv  Saved
# AXE downloaded
# Get Data for:  AXGN
# /Users/charliecoleman/Documents/investing_data/stocks/AXGN.csv  Saved
# AXGN downloaded
# Get Data for:  AXL
# /Users/charliecoleman/Documents/investing_data/stocks/AXL.csv  Saved
# AXL downloaded
# Get Data for:  AXNX
# /Users/charliecoleman/Documents/investing_data/stocks/AXNX.csv  Saved
# AXNX downloaded
# Get Data for:  AXP
# /Users/charliecoleman/Documents/investing_data/stocks/AXP.csv  Saved
# AXP downloaded
# Get Data for:  AXR
# /Users/charliecoleman/Documents/investing_data/stocks/AXR.csv  Saved
# AXR downloaded
# Get Data for:  AXS
# /Users/charliecoleman/Documents/investing_data/stocks/AXS.csv  Saved
# AXS downloaded
# Get Data for:  AXSM
# /Users/charliecoleman/Documents/investing_data/stocks/AXSM.csv  Saved
# AXSM downloaded
# Get Data for:  AXTA
# /Users/charliecoleman/Documents/investing_data/stocks/AXTA.csv  Saved
# AXTA downloaded
# Get Data for:  AXTI
# /Users/charliecoleman/Documents/investing_data/stocks/AXTI.csv  Saved
# AXTI downloaded
# Get Data for:  AYI
# /Users/charliecoleman/Documents/investing_data/stocks/AYI.csv  Saved
# AYI downloaded
# Get Data for:  AYX
# /Users/charliecoleman/Documents/investing_data/stocks/AYX.csv  Saved
# AYX downloaded
# Get Data for:  AZO
# /Users/charliecoleman/Documents/investing_data/stocks/AZO.csv  Saved
# AZO downloaded
# Get Data for:  AZPN
# /Users/charliecoleman/Documents/investing_data/stocks/AZPN.csv  Saved
# AZPN downloaded
# Get Data for:  AZZ
# /Users/charliecoleman/Documents/investing_data/stocks/AZZ.csv  Saved
# AZZ downloaded
# Get Data for:  B
# /Users/charliecoleman/Documents/investing_data/stocks/B.csv  Saved
# B downloaded
# Get Data for:  BA
# /Users/charliecoleman/Documents/investing_data/stocks/BA.csv  Saved
# BA downloaded
# Get Data for:  BAC
# /Users/charliecoleman/Documents/investing_data/stocks/BAC.csv  Saved
# BAC downloaded
# Get Data for:  BAH
# /Users/charliecoleman/Documents/investing_data/stocks/BAH.csv  Saved
# BAH downloaded
# Get Data for:  BANC
# /Users/charliecoleman/Documents/investing_data/stocks/BANC.csv  Saved
# BANC downloaded
# Get Data for:  BAND
# /Users/charliecoleman/Documents/investing_data/stocks/BAND.csv  Saved
# BAND downloaded
# Get Data for:  BANF
# /Users/charliecoleman/Documents/investing_data/stocks/BANF.csv  Saved
# BANF downloaded
# Get Data for:  BANR
# /Users/charliecoleman/Documents/investing_data/stocks/BANR.csv  Saved
# BANR downloaded
# Get Data for:  BASI
# - BASI: No data found, symbol may be delisted
# /Users/charliecoleman/Documents/investing_data/stocks/BASI.csv  Saved
# BASI downloaded
# Get Data for:  BATRA
# /Users/charliecoleman/Documents/investing_data/stocks/BATRA.csv  Saved
# BATRA downloaded
# Get Data for:  BATRK
# /Users/charliecoleman/Documents/investing_data/stocks/BATRK.csv  Saved
# BATRK downloaded
# Get Data for:  BAX
# /Users/charliecoleman/Documents/investing_data/stocks/BAX.csv  Saved
# BAX downloaded
# Get Data for:  BBBY
