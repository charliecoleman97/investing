# %% [markdown]
# ## Just need to enter a ticker and it will return an Ichimoku graph

# %%
import sys
sys.path.insert(0, '/Users/charlie/Documents/Git/charlie/investing/functions_modules.py')
import functions_modules as fm

# %%
plot = fm.take_ticker_and_make_ichimoku_plot('AAPL')
